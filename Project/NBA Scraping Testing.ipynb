# %%
import time
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Injuries

# %%
# URL page we will scraping (see image above)
url = "https://www.basketball-reference.com/friv/injuries.fcgi"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = [th.getText() for th in soup.findAll('tr')[0].findAll('th')]
headers
# Out:
# ['Player', 'Team', 'Update', 'Description']

# %%
players = []
for tr in soup.findAll('tr')[1:]:
    players.append(tr.findAll('th')[0].getText())
players
# Out:
# ['Kris Dunn',
#  'Danilo Gallinari',
#  "De'Andre Hunter",
#  'Cam Reddish',
#  'Tony Snell',
#  'Evan Fournier',
#  'Marcus Smart',
#  'Kemba Walker',
#  'Robert Williams',
#  'Chris Chiozza',
#  'Spencer Dinwiddie',
#  'Kevin Durant',
#  'James Harden',
#  'Tyler Johnson',
#  'LaMelo Ball',
#  'Nate Darling',
#  "Devonte' Graham",
#  'Gordon Hayward',
#  'Malik Monk',
#  'Zach LaVine',
#  'Damyean Dotson',
#  'Larry Nance',
#  'Dylan Windler',
#  'Tyrell Terry',
#  'Monte Morris',
#  'Jamal Murray',
#  'Sekou Doumbouya',
#  'Wayne Ellington',
#  'Jerami Grant',
#  'Cory Joseph',
#  'Rodney McGruder',
#  'Mason Plumlee',
#  'Dennis Smith',
#  'Stephen Curry',
#  'Kelly Oubre',
#  'Eric Paschall',
#  'Klay Thompson',
#  'Juan Toscano-Anderson',
#  'James Wiseman',
#  'D.J. Augustin',
#  'Sterling Brown',
#  'Dante Exum',
#  'Eric Gordon',
#  'Danuel House',
#  'David Nwaba',
#  'Jeremy Lamb',
#  'Doug McDermott',
#  'Domantas Sabonis',
#  'Myles Turner',
#  'T.J. Warren',
#  'Patrick Beverley',
#  'Serge Ibaka',
#  'Anthony Davis',
#  'Andre Drummond',
#  'Jared Dudley',
#  'Marc Gasol',
#  'LeBron James',
#  'Markieff Morris',
#  'Dennis Schröder',
#  'Dillon Brooks',
#  'Brandon Clarke',
#  'Jaren Jackson',
#  "De'Anthony Melton",
#  'Jonas Valančiūnas',
#  'Justise Winslow',
#  'Bam Adebayo',
#  'Jimmy Butler',
#  'Goran Dragić',
#  'Tyler Herro',
#  'Andre Iguodala',
#  'Victor Oladipo',
#  'Gabe Vincent',
#  'Malik Beasley',
#  'Jaylen Nowell',
#  'Nickeil Alexander-Walker',
#  'Josh Hart',
#  'Alec Burks',
#  'Mitchell Robinson',
#  'Gabriel Deck',
#  'Luguentz Dort',
#  'Shai Gilgeous-Alexander',
#  'Josh Hall',
#  'Mike Muscala',
#  'Isaiah Roby',
#  'Michael Carter-Williams',
#  'James Ennis',
#  'Markelle Fultz',
#  'Jonathan Isaac',
#  'Otto Porter',
#  'Terrence Ross',
#  'Seth Curry',
#  'Tobias Harris',
#  'George Hill',
#  'Dwight Howard',
#  'Ben Simmons',
#  'Abdel Nader',
#  'Zach Collins',
#  'Damian Lillard',
#  'Marvin Bagley',
#  'Richaun Holmes',
#  'Trey Lyles',
#  'OG Anunoby',
#  'Jalen Harris',
#  'Pascal Siakam',
#  'Fred VanVleet',
#  'Udoka Azubuike',
#  'Mike Conley',
#  'Derrick Favors',
#  'Rudy Gobert',
#  'Ersan İlyasova',
#  'Donovan Mitchell',
#  'Thomas Bryant',
#  'Rui Hachimura',
#  'Alex Len']

# %%
rows = soup.findAll('tr')[1:]
inj = [[td.getText() for td in rows[i].findAll('td')] for i in range(len(rows))]
inj
# Out:
# [['Atlanta Hawks',
#   'Thu, Mar 18, 2021',
#   "Out (Ankle) - The Hawks announced that Dunn returned to practice yesterday and his status will be updated on the team's upcoming road trip."],
#  ['Atlanta Hawks',
#   'Mon, Apr 19, 2021',
#   "Out (Foot) - Gallinari is listed as OUT for Tuesday's (Apr. 20) game."],
#  ['Atlanta Hawks',
#   'Mon, Apr 5, 2021',
#   'Out (Knee) - The Hawks announced that Hunter underwent a non-surgical procedure and will return to activity later this week.'],
#  ['Atlanta Hawks',
#   'Tue, Apr 13, 2021',
#   'Out (Achilles) - The Hawks announced that Reddish is running and shooting and will be re-evaluated in two weeks.'],
#  ['Atlanta Hawks',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Snell did not play in Sunday's game (April 18) against Indiana."],
#  ['Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Out (Health and Safety Protocols) - Fournier is out for Monday's (Apr. 19) game against Chicago."],
#  ['Boston Celtics',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Illness) - Smart is questionable for Monday's (Apr. 19) game against Chicago."],
#  ['Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Illness) - Walker is questionable for Monday's (Apr. 19) game against Chicago."],
#  ['Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Williams III is out for Monday's (Apr. 19) game against Chicago."],
#  ['Brooklyn Nets',
#   'Wed, Apr 14, 2021',
#   'Out (Hand) - The Nets announced that Chiozza had surgery on his right hand.'],
#  ['Brooklyn Nets',
#   'Tue, Jan 19, 2021',
#   'Out For Season (ACL) - Dinwiddie had a ACL reconstruction of his right knee, according to Brian Lewis of the New York Post. He will miss the rest of the season.'],
#  ['Brooklyn Nets',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Durant left Sunday's (Apr. 18) game against Miami and will not return."],
#  ['Brooklyn Nets',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hamstring) - Harden did not play in Sunday's game (Apr. 18) against Miami."],
#  ['Brooklyn Nets',
#   'Mon, Apr 5, 2021',
#   'Out (Knee) - The Nets announced that Johnson is out indefinitely with knee soreness.'],
#  ['Charlotte Hornets',
#   'Wed, Mar 24, 2021',
#   'Out (Wrist) - Ball had surgery on his fractured wrist and will be re-evaluated in four weeks, according to Shams Charania of The Athletic.'],
#  ['Charlotte Hornets',
#   'Mon, Apr 19, 2021',
#   "Out (Ankle) - Darling is out for Tuesday's (Apr. 20) game against New York."],
#  ['Charlotte Hornets',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Quad) - Graham is questionable for Tuesday's (Apr. 20) game against New York."],
#  ['Charlotte Hornets',
#   'Sat, Apr 3, 2021',
#   'Out (Foot) - The Hornets announced that Hayward will be re-evaluated in about four weeks.'],
#  ['Charlotte Hornets',
#   'Fri, Apr 2, 2021',
#   'Out (Ankle) - Monk is expected to miss at least two weeks, according to Rod Boone of The Hive Vibes.'],
#  ['Chicago Bulls',
#   'Thu, Apr 15, 2021',
#   "Out (Health and Safety Protocols) - LaVine is expected to miss several games after entering to the NBA's health and safety protocols, according to Adrian Wojnarowski of ESPN."],
#  ['Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Dotson is out for Monday's (Apr. 19) game against Detroit."],
#  ['Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Personal) - Nance Jr. is out for Monday's (Apr. 19) game against Detroit."],
#  ['Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Windler is out for Monday's (Apr. 19) game against Detroit."],
#  ['Dallas Mavericks',
#   'Thu, Apr 15, 2021',
#   'Out (Personal) - Terry has not played since mid-March and no timetable has been announced for his return.'],
#  ['Denver Nuggets',
#   'Sun, Apr 18, 2021',
#   "Out (Hamstring) - Morris is out for Monday's (Apr. 19) game against Memphis."],
#  ['Denver Nuggets',
#   'Tue, Apr 13, 2021',
#   'Out For Season (Knee) - The Nuggets announced that Murray tore his left ACL. He will miss the rest of the season.'],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Neck) - Doumbouya is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Rest) - Ellington is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Quad) - Grant is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Illness) - Joseph is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Elbow) - McGruder is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Rest) - Plumlee is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Smith Jr. is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Curry is questionable for Monday's (Apr. 19) game against Philadelphia."],
#  ['Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Wrist) - Oubre Jr. is questionable for Monday's (Apr. 19) game against Philadelphia."],
#  ['Golden State Warriors',
#   'Sun, Apr 4, 2021',
#   'Out (Hip) - The Warriors announced that Paschall will miss at least two weeks.'],
#  ['Golden State Warriors',
#   'Fri, Feb 26, 2021',
#   "Out For Season (Right Achilles) - Thompson's recovery from a torn right Achilles tendon is right on schedule, according to Connor Letourneau of the San Francisco Chronicle. He's out of a walking boot and starting mobility exercises."],
#  ['Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Out (Concussion) - Toscano-Anderson is out for Monday's (Apr. 19) game against Philadelphia."],
#  ['Golden State Warriors',
#   'Thu, Apr 15, 2021',
#   'Out For Season (Knee) - The Warriors announced that Wiseman will miss the rest of the season.'],
#  ['Houston Rockets',
#   'Thu, Apr 15, 2021',
#   'Out (Ankle) - Augustin is wearing a walking boot and underwent an MRI on his ankle, according to Adam Spolane of Sports Radio 610 Houston.'],
#  ['Houston Rockets',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Rockets coach Stephen Silas said Brown will miss Sunday's (Apr. 18) and Monday's (Apr. 19) games against Orlando and Miami."],
#  ['Houston Rockets',
#   'Fri, Mar 5, 2021',
#   'Out (Calf) - Exum is still in a walking boot and no timetable has been announced for when he might return, according to Ben DuBose of USA Today.'],
#  ['Houston Rockets',
#   'Fri, Mar 12, 2021',
#   'Out (Groin) - Gordon is dealing with a moderate groin strain and is expected to miss 4-6 weeks, according to Adrian Wojnarowski of ESPN.'],
#  ['Houston Rockets',
#   'Thu, Apr 15, 2021',
#   "Out (Ankle) - House Jr. isn't expected to return by Monday's (Apr. 19) game against Miami, according to Mark Berman of Fox 26 Houston."],
#  ['Houston Rockets',
#   'Tue, Mar 16, 2021',
#   'Out (Wrist) - Nwaba re-aggravated his strained right wrist and is likely to miss an extended period of time, according to Ben DuBose of USA Today.'],
#  ['Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Knee) - Lamb is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - McDermott is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Back) - Sabonis is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Toe) - Turner is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Indiana Pacers',
#   'Thu, Mar 25, 2021',
#   'Out For Season (Foot) - Warren underwent foot surgery and will miss the rest of the season, according to Scott Agness of the Fieldhouse Files.'],
#  ['Los Angeles Clippers',
#   'Fri, Apr 9, 2021',
#   'Out (Hand) - The Clippers announced G Patrick Beverley will be re-evaluated in the next 3 to 4 weeks.'],
#  ['Los Angeles Clippers',
#   'Sun, Apr 11, 2021',
#   "Out (Back) - Ibaka will not play in the Clippers' upcoming three-game road trip, according to Andrew Greif of the Los Angeles Times."],
#  ['Los Angeles Lakers',
#   'Sat, Apr 10, 2021',
#   'Out (Achilles) - Davis will be re-evaluated on Thursday (Apr. 15) and could return in the next week to 10 days, according to Dave McMenamin of ESPN.'],
#  ['Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Toe) - Drummond is probable for Monday's (Apr. 19) game against Utah."],
#  ['Los Angeles Lakers',
#   'Sun, Mar 14, 2021',
#   'Out (Knee) - The Lakers announced that Dudley has been diagnosed with a torn MCL.'],
#  ['Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Finger) - Gasol is probable for Monday's (Apr. 19) game against Utah."],
#  ['Los Angeles Lakers',
#   'Thu, Mar 25, 2021',
#   'Out (Ankle) - James is expected to miss 3-5 more weeks, according to Shams Charania of The Athletic.'],
#  ['Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Morris is probable for Monday's (Apr. 19) game against Utah."],
#  ['Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Foot) - Schroder is probable for Monday's (Apr. 19) game against Utah."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Brooks is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hip) - Clarke is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Jackson Jr. is doubtful for Monday's (Apr. 19) game against Denver."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Leg) - Melton is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Out (Concussion) - Valanciunas is out for Monday's (Apr. 19) game against Denver."],
#  ['Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Winslow is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Out (Knee) - Adebayo is out for Monday's (Apr. 19) game against Houston."],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - Butler is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Injury recovery) - Dragic is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Foot) - Herro is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - Iguodala is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Miami Heat',
#   'Fri, Apr 9, 2021',
#   'Out (Knee) - The Heat announced G Victor Oladipo will miss at least the next 4 games.'],
#  ['Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Knee) - Vincent is probable for Monday's (Apr. 19) game against Houston."],
#  ['Minnesota Timberwolves',
#   'Mon, Apr 5, 2021',
#   'Out (Hamstring) - Beasley will miss the next 4-to-6 weeks with a Grade 3 left hamstring strain.'],
#  ['Minnesota Timberwolves',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Tibia) - Nowell did not play in Sunday's game (Apr. 18) against the Clippers."],
#  ['New Orleans Pelicans',
#   'Tue, Apr 6, 2021',
#   'Out (Ankle) - The Pelicans announced Alexander-Walker will be re-evaluated in two weeks.'],
#  ['New Orleans Pelicans',
#   'Tue, Apr 6, 2021',
#   'Out (Thumb) - The Pelicans announced that Hart will be re-examined in approximately three weeks.'],
#  ['New York Knicks',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Health and Safety Protocols) - Burks did not play in Sunday's game (Apr. 18) against New Orleans."],
#  ['New York Knicks',
#   'Sun, Mar 28, 2021',
#   'Out (Ankle) - The Knicks announced that Robinson suffered a fractured foot and is out indefinitely.'],
#  ['Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Not With Team) - Deck is out for Monday's (Apr. 19) game against Washington."],
#  ['Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Hip) - Dort is out for Monday's (Apr. 19) game against Washington."],
#  ['Oklahoma City Thunder',
#   'Fri, Apr 16, 2021',
#   'Out (Foot) - Gilgeous-Alexander will miss at least two more weeks, according to Rylan Stiles of BricktownBuckets.com.'],
#  ['Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Knee) - Hall is out for Monday's (Apr. 19) game against Washington."],
#  ['Oklahoma City Thunder',
#   'Thu, Apr 15, 2021',
#   'Out (Ankle) - Muscala has not played since Mar. 14 against Memphis. There is currently no timetable for his return.'],
#  ['Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Toe) - Roby is out for Monday's (Apr. 19) game against Washington."],
#  ['Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - Carter-Williams did not play in Sunday's (Apr. 18) game against Houston."],
#  ['Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Calf) - Ennis III is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Orlando Magic',
#   'Wed, Jan 6, 2021',
#   'Out For Season (Knee) - Fultz will miss the rest of the season with a torn ACL in his left knee, according to Adrian Wojnarowski.'],
#  ['Orlando Magic',
#   'Fri, Mar 5, 2021',
#   "Out For Season (Knee) - Isaac is making progress with his rehab. He's started to ramp up his on-court work, according to Roy Parry of the Orlando Sentinel. He's not slated to return this season, but should be ready to go for the 2021-2022 season."],
#  ['Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Foot) - Porter Jr. is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Back) - Ross is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hip) - Curry is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Harris is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thumb) - Hill is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Howard is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Philadelphia 76ers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Illness) - Simmons is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Phoenix Suns',
#   'Sat, Apr 17, 2021',
#   'Out (Knee) - Nader has not played since Mar. 21 against the Lakers. The timetable for his return is unknown.'],
#  ['Portland Trail Blazers',
#   'Fri, Mar 5, 2021',
#   "Out (Ankle) - Collins is rehabbing after having surgery to repair a stress fracture in his ankle, according to a report from NBC Sports Northwest. If everything goes to plan, there's a chance he could return in time for the playoffs."],
#  ['Portland Trail Blazers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hamstring) - Lillard did not play in Sunday's game (Apr. 18) against Charlotte."],
#  ['Sacramento Kings',
#   'Thu, Mar 18, 2021',
#   'Out (Hand) - The Kings announced Bagley will not require surgery, but will be re-evaluated in approximately four weeks.'],
#  ['Sacramento Kings',
#   'Wed, Apr 14, 2021',
#   'Out (Hamstring) - The Kings announced C Richaun Holmes will miss at least the next three games.'],
#  ['San Antonio Spurs',
#   'Sun, Apr 18, 2021',
#   "Out (Ankle) - Lyles is out for Monday's (Apr. 19) game against Indiana."],
#  ['Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Calf) - Anunoby did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - Harris did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Shoulder) - Siakam did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - VanVleet did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Utah Jazz',
#   'Fri, Feb 12, 2021',
#   'Out (Ankle) - Azubuike is out indefinitely with a severe right ankle sprain, according to Sarah Todd of The Deseret News.'],
#  ['Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Conley is probable for Monday's (Apr. 19) game against the Lakers."],
#  ['Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Favors is questionable for Monday's (Apr. 19) game against the Lakers."],
#  ['Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Gobert is probable for Monday's (Apr. 19) game against the Lakers."],
#  ['Utah Jazz',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hamstring) - Ilyasova is doubtful for Monday's (Apr. 19) game against the Lakers."],
#  ['Utah Jazz',
#   'Sat, Apr 17, 2021',
#   'Out (Ankle) - The Jazz announced that Mitchell will be re-evaluated in a week.'],
#  ['Washington Wizards',
#   'Tue, Feb 2, 2021',
#   "Out For Season (Left knee) - The Wizards announced that Bryant had surgery to repair his left ACL. He's not expected to play again this season."],
#  ['Washington Wizards',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Hachimura is out for Monday's (Apr. 19) game against Oklahoma City."],
#  ['Washington Wizards',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Len is questionable for Monday's (Apr. 19) game against Oklahoma City."]]

# %%
for i in range(len(inj)):
    inj[i].insert(0,players[i])
inj
# Out:
# [['Kris Dunn',
#   'Atlanta Hawks',
#   'Thu, Mar 18, 2021',
#   "Out (Ankle) - The Hawks announced that Dunn returned to practice yesterday and his status will be updated on the team's upcoming road trip."],
#  ['Danilo Gallinari',
#   'Atlanta Hawks',
#   'Mon, Apr 19, 2021',
#   "Out (Foot) - Gallinari is listed as OUT for Tuesday's (Apr. 20) game."],
#  ["De'Andre Hunter",
#   'Atlanta Hawks',
#   'Mon, Apr 5, 2021',
#   'Out (Knee) - The Hawks announced that Hunter underwent a non-surgical procedure and will return to activity later this week.'],
#  ['Cam Reddish',
#   'Atlanta Hawks',
#   'Tue, Apr 13, 2021',
#   'Out (Achilles) - The Hawks announced that Reddish is running and shooting and will be re-evaluated in two weeks.'],
#  ['Tony Snell',
#   'Atlanta Hawks',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Snell did not play in Sunday's game (April 18) against Indiana."],
#  ['Evan Fournier',
#   'Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Out (Health and Safety Protocols) - Fournier is out for Monday's (Apr. 19) game against Chicago."],
#  ['Marcus Smart',
#   'Boston Celtics',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Illness) - Smart is questionable for Monday's (Apr. 19) game against Chicago."],
#  ['Kemba Walker',
#   'Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Illness) - Walker is questionable for Monday's (Apr. 19) game against Chicago."],
#  ['Robert Williams',
#   'Boston Celtics',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Williams III is out for Monday's (Apr. 19) game against Chicago."],
#  ['Chris Chiozza',
#   'Brooklyn Nets',
#   'Wed, Apr 14, 2021',
#   'Out (Hand) - The Nets announced that Chiozza had surgery on his right hand.'],
#  ['Spencer Dinwiddie',
#   'Brooklyn Nets',
#   'Tue, Jan 19, 2021',
#   'Out For Season (ACL) - Dinwiddie had a ACL reconstruction of his right knee, according to Brian Lewis of the New York Post. He will miss the rest of the season.'],
#  ['Kevin Durant',
#   'Brooklyn Nets',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Durant left Sunday's (Apr. 18) game against Miami and will not return."],
#  ['James Harden',
#   'Brooklyn Nets',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hamstring) - Harden did not play in Sunday's game (Apr. 18) against Miami."],
#  ['Tyler Johnson',
#   'Brooklyn Nets',
#   'Mon, Apr 5, 2021',
#   'Out (Knee) - The Nets announced that Johnson is out indefinitely with knee soreness.'],
#  ['LaMelo Ball',
#   'Charlotte Hornets',
#   'Wed, Mar 24, 2021',
#   'Out (Wrist) - Ball had surgery on his fractured wrist and will be re-evaluated in four weeks, according to Shams Charania of The Athletic.'],
#  ['Nate Darling',
#   'Charlotte Hornets',
#   'Mon, Apr 19, 2021',
#   "Out (Ankle) - Darling is out for Tuesday's (Apr. 20) game against New York."],
#  ["Devonte' Graham",
#   'Charlotte Hornets',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Quad) - Graham is questionable for Tuesday's (Apr. 20) game against New York."],
#  ['Gordon Hayward',
#   'Charlotte Hornets',
#   'Sat, Apr 3, 2021',
#   'Out (Foot) - The Hornets announced that Hayward will be re-evaluated in about four weeks.'],
#  ['Malik Monk',
#   'Charlotte Hornets',
#   'Fri, Apr 2, 2021',
#   'Out (Ankle) - Monk is expected to miss at least two weeks, according to Rod Boone of The Hive Vibes.'],
#  ['Zach LaVine',
#   'Chicago Bulls',
#   'Thu, Apr 15, 2021',
#   "Out (Health and Safety Protocols) - LaVine is expected to miss several games after entering to the NBA's health and safety protocols, according to Adrian Wojnarowski of ESPN."],
#  ['Damyean Dotson',
#   'Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Dotson is out for Monday's (Apr. 19) game against Detroit."],
#  ['Larry Nance',
#   'Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Personal) - Nance Jr. is out for Monday's (Apr. 19) game against Detroit."],
#  ['Dylan Windler',
#   'Cleveland Cavaliers',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Windler is out for Monday's (Apr. 19) game against Detroit."],
#  ['Tyrell Terry',
#   'Dallas Mavericks',
#   'Thu, Apr 15, 2021',
#   'Out (Personal) - Terry has not played since mid-March and no timetable has been announced for his return.'],
#  ['Monte Morris',
#   'Denver Nuggets',
#   'Sun, Apr 18, 2021',
#   "Out (Hamstring) - Morris is out for Monday's (Apr. 19) game against Memphis."],
#  ['Jamal Murray',
#   'Denver Nuggets',
#   'Tue, Apr 13, 2021',
#   'Out For Season (Knee) - The Nuggets announced that Murray tore his left ACL. He will miss the rest of the season.'],
#  ['Sekou Doumbouya',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Neck) - Doumbouya is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Wayne Ellington',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Rest) - Ellington is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Jerami Grant',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Quad) - Grant is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Cory Joseph',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Illness) - Joseph is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Rodney McGruder',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Elbow) - McGruder is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Mason Plumlee',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Rest) - Plumlee is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Dennis Smith',
#   'Detroit Pistons',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Smith Jr. is out for Monday's (Apr. 19) game against Cleveland."],
#  ['Stephen Curry',
#   'Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Curry is questionable for Monday's (Apr. 19) game against Philadelphia."],
#  ['Kelly Oubre',
#   'Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Wrist) - Oubre Jr. is questionable for Monday's (Apr. 19) game against Philadelphia."],
#  ['Eric Paschall',
#   'Golden State Warriors',
#   'Sun, Apr 4, 2021',
#   'Out (Hip) - The Warriors announced that Paschall will miss at least two weeks.'],
#  ['Klay Thompson',
#   'Golden State Warriors',
#   'Fri, Feb 26, 2021',
#   "Out For Season (Right Achilles) - Thompson's recovery from a torn right Achilles tendon is right on schedule, according to Connor Letourneau of the San Francisco Chronicle. He's out of a walking boot and starting mobility exercises."],
#  ['Juan Toscano-Anderson',
#   'Golden State Warriors',
#   'Sun, Apr 18, 2021',
#   "Out (Concussion) - Toscano-Anderson is out for Monday's (Apr. 19) game against Philadelphia."],
#  ['James Wiseman',
#   'Golden State Warriors',
#   'Thu, Apr 15, 2021',
#   'Out For Season (Knee) - The Warriors announced that Wiseman will miss the rest of the season.'],
#  ['D.J. Augustin',
#   'Houston Rockets',
#   'Thu, Apr 15, 2021',
#   'Out (Ankle) - Augustin is wearing a walking boot and underwent an MRI on his ankle, according to Adam Spolane of Sports Radio 610 Houston.'],
#  ['Sterling Brown',
#   'Houston Rockets',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Rockets coach Stephen Silas said Brown will miss Sunday's (Apr. 18) and Monday's (Apr. 19) games against Orlando and Miami."],
#  ['Dante Exum',
#   'Houston Rockets',
#   'Fri, Mar 5, 2021',
#   'Out (Calf) - Exum is still in a walking boot and no timetable has been announced for when he might return, according to Ben DuBose of USA Today.'],
#  ['Eric Gordon',
#   'Houston Rockets',
#   'Fri, Mar 12, 2021',
#   'Out (Groin) - Gordon is dealing with a moderate groin strain and is expected to miss 4-6 weeks, according to Adrian Wojnarowski of ESPN.'],
#  ['Danuel House',
#   'Houston Rockets',
#   'Thu, Apr 15, 2021',
#   "Out (Ankle) - House Jr. isn't expected to return by Monday's (Apr. 19) game against Miami, according to Mark Berman of Fox 26 Houston."],
#  ['David Nwaba',
#   'Houston Rockets',
#   'Tue, Mar 16, 2021',
#   'Out (Wrist) - Nwaba re-aggravated his strained right wrist and is likely to miss an extended period of time, according to Ben DuBose of USA Today.'],
#  ['Jeremy Lamb',
#   'Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Knee) - Lamb is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Doug McDermott',
#   'Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - McDermott is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Domantas Sabonis',
#   'Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Back) - Sabonis is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['Myles Turner',
#   'Indiana Pacers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Toe) - Turner is questionable for Monday's (Apr. 19) game against San Antonio."],
#  ['T.J. Warren',
#   'Indiana Pacers',
#   'Thu, Mar 25, 2021',
#   'Out For Season (Foot) - Warren underwent foot surgery and will miss the rest of the season, according to Scott Agness of the Fieldhouse Files.'],
#  ['Patrick Beverley',
#   'Los Angeles Clippers',
#   'Fri, Apr 9, 2021',
#   'Out (Hand) - The Clippers announced G Patrick Beverley will be re-evaluated in the next 3 to 4 weeks.'],
#  ['Serge Ibaka',
#   'Los Angeles Clippers',
#   'Sun, Apr 11, 2021',
#   "Out (Back) - Ibaka will not play in the Clippers' upcoming three-game road trip, according to Andrew Greif of the Los Angeles Times."],
#  ['Anthony Davis',
#   'Los Angeles Lakers',
#   'Sat, Apr 10, 2021',
#   'Out (Achilles) - Davis will be re-evaluated on Thursday (Apr. 15) and could return in the next week to 10 days, according to Dave McMenamin of ESPN.'],
#  ['Andre Drummond',
#   'Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Toe) - Drummond is probable for Monday's (Apr. 19) game against Utah."],
#  ['Jared Dudley',
#   'Los Angeles Lakers',
#   'Sun, Mar 14, 2021',
#   'Out (Knee) - The Lakers announced that Dudley has been diagnosed with a torn MCL.'],
#  ['Marc Gasol',
#   'Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Finger) - Gasol is probable for Monday's (Apr. 19) game against Utah."],
#  ['LeBron James',
#   'Los Angeles Lakers',
#   'Thu, Mar 25, 2021',
#   'Out (Ankle) - James is expected to miss 3-5 more weeks, according to Shams Charania of The Athletic.'],
#  ['Markieff Morris',
#   'Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Ankle) - Morris is probable for Monday's (Apr. 19) game against Utah."],
#  ['Dennis Schröder',
#   'Los Angeles Lakers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Foot) - Schroder is probable for Monday's (Apr. 19) game against Utah."],
#  ['Dillon Brooks',
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Brooks is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Brandon Clarke',
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hip) - Clarke is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Jaren Jackson',
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Jackson Jr. is doubtful for Monday's (Apr. 19) game against Denver."],
#  ["De'Anthony Melton",
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Leg) - Melton is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Jonas Valančiūnas',
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Out (Concussion) - Valanciunas is out for Monday's (Apr. 19) game against Denver."],
#  ['Justise Winslow',
#   'Memphis Grizzlies',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thigh) - Winslow is questionable for Monday's (Apr. 19) game against Denver."],
#  ['Bam Adebayo',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Out (Knee) - Adebayo is out for Monday's (Apr. 19) game against Houston."],
#  ['Jimmy Butler',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - Butler is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Goran Dragić',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Injury recovery) - Dragic is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Tyler Herro',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Foot) - Herro is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Andre Iguodala',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - Iguodala is questionable for Monday's (Apr. 19) game against Houston."],
#  ['Victor Oladipo',
#   'Miami Heat',
#   'Fri, Apr 9, 2021',
#   'Out (Knee) - The Heat announced G Victor Oladipo will miss at least the next 4 games.'],
#  ['Gabe Vincent',
#   'Miami Heat',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Knee) - Vincent is probable for Monday's (Apr. 19) game against Houston."],
#  ['Malik Beasley',
#   'Minnesota Timberwolves',
#   'Mon, Apr 5, 2021',
#   'Out (Hamstring) - Beasley will miss the next 4-to-6 weeks with a Grade 3 left hamstring strain.'],
#  ['Jaylen Nowell',
#   'Minnesota Timberwolves',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Tibia) - Nowell did not play in Sunday's game (Apr. 18) against the Clippers."],
#  ['Nickeil Alexander-Walker',
#   'New Orleans Pelicans',
#   'Tue, Apr 6, 2021',
#   'Out (Ankle) - The Pelicans announced Alexander-Walker will be re-evaluated in two weeks.'],
#  ['Josh Hart',
#   'New Orleans Pelicans',
#   'Tue, Apr 6, 2021',
#   'Out (Thumb) - The Pelicans announced that Hart will be re-examined in approximately three weeks.'],
#  ['Alec Burks',
#   'New York Knicks',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Health and Safety Protocols) - Burks did not play in Sunday's game (Apr. 18) against New Orleans."],
#  ['Mitchell Robinson',
#   'New York Knicks',
#   'Sun, Mar 28, 2021',
#   'Out (Ankle) - The Knicks announced that Robinson suffered a fractured foot and is out indefinitely.'],
#  ['Gabriel Deck',
#   'Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Not With Team) - Deck is out for Monday's (Apr. 19) game against Washington."],
#  ['Luguentz Dort',
#   'Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Hip) - Dort is out for Monday's (Apr. 19) game against Washington."],
#  ['Shai Gilgeous-Alexander',
#   'Oklahoma City Thunder',
#   'Fri, Apr 16, 2021',
#   'Out (Foot) - Gilgeous-Alexander will miss at least two more weeks, according to Rylan Stiles of BricktownBuckets.com.'],
#  ['Josh Hall',
#   'Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Knee) - Hall is out for Monday's (Apr. 19) game against Washington."],
#  ['Mike Muscala',
#   'Oklahoma City Thunder',
#   'Thu, Apr 15, 2021',
#   'Out (Ankle) - Muscala has not played since Mar. 14 against Memphis. There is currently no timetable for his return.'],
#  ['Isaiah Roby',
#   'Oklahoma City Thunder',
#   'Mon, Apr 19, 2021',
#   "Out (Toe) - Roby is out for Monday's (Apr. 19) game against Washington."],
#  ['Michael Carter-Williams',
#   'Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Ankle) - Carter-Williams did not play in Sunday's (Apr. 18) game against Houston."],
#  ['James Ennis',
#   'Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Calf) - Ennis III is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Markelle Fultz',
#   'Orlando Magic',
#   'Wed, Jan 6, 2021',
#   'Out For Season (Knee) - Fultz will miss the rest of the season with a torn ACL in his left knee, according to Adrian Wojnarowski.'],
#  ['Jonathan Isaac',
#   'Orlando Magic',
#   'Fri, Mar 5, 2021',
#   "Out For Season (Knee) - Isaac is making progress with his rehab. He's started to ramp up his on-court work, according to Roy Parry of the Orlando Sentinel. He's not slated to return this season, but should be ready to go for the 2021-2022 season."],
#  ['Otto Porter',
#   'Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Foot) - Porter Jr. is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Terrence Ross',
#   'Orlando Magic',
#   'Mon, Apr 19, 2021',
#   "Out (Back) - Ross is out for Tuesday's (Apr. 20) game against Atlanta."],
#  ['Seth Curry',
#   'Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Hip) - Curry is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Tobias Harris',
#   'Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Harris is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['George Hill',
#   'Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Thumb) - Hill is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Dwight Howard',
#   'Philadelphia 76ers',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Howard is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Ben Simmons',
#   'Philadelphia 76ers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Illness) - Simmons is questionable for Monday's (Apr. 19) game against Golden State."],
#  ['Abdel Nader',
#   'Phoenix Suns',
#   'Sat, Apr 17, 2021',
#   'Out (Knee) - Nader has not played since Mar. 21 against the Lakers. The timetable for his return is unknown.'],
#  ['Zach Collins',
#   'Portland Trail Blazers',
#   'Fri, Mar 5, 2021',
#   "Out (Ankle) - Collins is rehabbing after having surgery to repair a stress fracture in his ankle, according to a report from NBC Sports Northwest. If everything goes to plan, there's a chance he could return in time for the playoffs."],
#  ['Damian Lillard',
#   'Portland Trail Blazers',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hamstring) - Lillard did not play in Sunday's game (Apr. 18) against Charlotte."],
#  ['Marvin Bagley',
#   'Sacramento Kings',
#   'Thu, Mar 18, 2021',
#   'Out (Hand) - The Kings announced Bagley will not require surgery, but will be re-evaluated in approximately four weeks.'],
#  ['Richaun Holmes',
#   'Sacramento Kings',
#   'Wed, Apr 14, 2021',
#   'Out (Hamstring) - The Kings announced C Richaun Holmes will miss at least the next three games.'],
#  ['Trey Lyles',
#   'San Antonio Spurs',
#   'Sun, Apr 18, 2021',
#   "Out (Ankle) - Lyles is out for Monday's (Apr. 19) game against Indiana."],
#  ['OG Anunoby',
#   'Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Calf) - Anunoby did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Jalen Harris',
#   'Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - Harris did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Pascal Siakam',
#   'Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Shoulder) - Siakam did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Fred VanVleet',
#   'Toronto Raptors',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hip) - VanVleet did not play in Sunday's (Apr. 18) game against Oklahoma City."],
#  ['Udoka Azubuike',
#   'Utah Jazz',
#   'Fri, Feb 12, 2021',
#   'Out (Ankle) - Azubuike is out indefinitely with a severe right ankle sprain, according to Sarah Todd of The Deseret News.'],
#  ['Mike Conley',
#   'Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Conley is probable for Monday's (Apr. 19) game against the Lakers."],
#  ['Derrick Favors',
#   'Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Favors is questionable for Monday's (Apr. 19) game against the Lakers."],
#  ['Rudy Gobert',
#   'Utah Jazz',
#   'Sun, Apr 18, 2021',
#   "Day To Day (Knee) - Gobert is probable for Monday's (Apr. 19) game against the Lakers."],
#  ['Ersan İlyasova',
#   'Utah Jazz',
#   'Mon, Apr 19, 2021',
#   "Day To Day (Hamstring) - Ilyasova is doubtful for Monday's (Apr. 19) game against the Lakers."],
#  ['Donovan Mitchell',
#   'Utah Jazz',
#   'Sat, Apr 17, 2021',
#   'Out (Ankle) - The Jazz announced that Mitchell will be re-evaluated in a week.'],
#  ['Thomas Bryant',
#   'Washington Wizards',
#   'Tue, Feb 2, 2021',
#   "Out For Season (Left knee) - The Wizards announced that Bryant had surgery to repair his left ACL. He's not expected to play again this season."],
#  ['Rui Hachimura',
#   'Washington Wizards',
#   'Sun, Apr 18, 2021',
#   "Out (Knee) - Hachimura is out for Monday's (Apr. 19) game against Oklahoma City."],
# 64   Day To Day (Thigh) - Winslow is questionable f...
# 65   Out (Knee) - Adebayo is out for Monday's (Apr....
# 66   Day To Day (Ankle) - Butler is questionable fo...
# 67   Day To Day (Injury recovery) - Dragic is quest...
# 68   Day To Day (Foot) - Herro is questionable for ...
# 69   Day To Day (Hip) - Iguodala is questionable fo...
# 70   Out (Knee) - The Heat announced G Victor Oladi...
# 71   Day To Day (Knee) - Vincent is probable for Mo...
# 72   Out (Hamstring) - Beasley will miss the next 4...
# 73   Day To Day (Tibia) - Nowell did not play in Su...
# 74   Out (Ankle) - The Pelicans announced Alexander...
# 75   Out (Thumb) - The Pelicans announced that Hart...
# 76   Day To Day (Health and Safety Protocols) - Bur...
# 77   Out (Ankle) - The Knicks announced that Robins...
# 78   Out (Not With Team) - Deck is out for Monday's...
# 79   Out (Hip) - Dort is out for Monday's (Apr. 19)...
# 80   Out (Foot) - Gilgeous-Alexander will miss at l...
# 81   Out (Knee) - Hall is out for Monday's (Apr. 19...
# 82   Out (Ankle) - Muscala has not played since Mar...
# 83   Out (Toe) - Roby is out for Monday's (Apr. 19)...
# 84   Day To Day (Ankle) - Carter-Williams did not p...
# 85   Out (Calf) - Ennis III is out for Tuesday's (A...
# 86   Out For Season (Knee) - Fultz will miss the re...
# 87   Out For Season (Knee) - Isaac is making progre...
# 88   Out (Foot) - Porter Jr. is out for Tuesday's (...
# 89   Out (Back) - Ross is out for Tuesday's (Apr. 2...
# 90   Day To Day (Hip) - Curry is questionable for M...
# 91   Day To Day (Knee) - Harris is questionable for...
# 92   Day To Day (Thumb) - Hill is questionable for ...
# 93   Day To Day (Knee) - Howard is questionable for...
# 94   Day To Day (Illness) - Simmons is questionable...
# 95   Out (Knee) - Nader has not played since Mar. 2...
# 96   Out (Ankle) - Collins is rehabbing after havin...
# 97   Day To Day (Hamstring) - Lillard did not play ...
# 98   Out (Hand) - The Kings announced Bagley will n...
# 99   Out (Hamstring) - The Kings announced C Richau...
# 100  Out (Ankle) - Lyles is out for Monday's (Apr. ...
# 101  Day To Day (Calf) - Anunoby did not play in Su...
# 102  Day To Day (Hip) - Harris did not play in Sund...
# 103  Day To Day (Shoulder) - Siakam did not play in...
# 104  Day To Day (Hip) - VanVleet did not play in Su...
# 105  Out (Ankle) - Azubuike is out indefinitely wit...
# 106  Day To Day (Knee) - Conley is probable for Mon...
# 107  Day To Day (Knee) - Favors is questionable for...
# 108  Day To Day (Knee) - Gobert is probable for Mon...
# 109  Day To Day (Hamstring) - Ilyasova is doubtful ...
# 110  Out (Ankle) - The Jazz announced that Mitchell...
# 111  Out For Season (Left knee) - The Wizards annou...
# 112  Out (Knee) - Hachimura is out for Monday's (Ap...
# 113  Day To Day (Ankle) - Len is questionable for M...

# %% [markdown]
# # Today's games

# %%
import json

# %%
with urlopen("https://cdn.nba.com/static/json/liveData/scoreboard/todaysScoreboard_00.json") as url:
    data = json.loads(url.read().decode())
    print(data['scoreboard']['games'])
# Out:
# [{'gameId': '0022000868', 'gameCode': '20210419/CLEDET', 'gameStatus': 3, 'gameStatusText': 'Final', 'period': 4, 'gameClock': '', 'gameTimeUTC': '2021-04-19T23:00:00Z', 'gameEt': '2021-04-19T19:00:00Z', 'regulationPeriods': 4, 'seriesGameNumber': '', 'seriesText': '', 'homeTeam': {'teamId': 1610612765, 'teamName': 'Pistons', 'teamCity': 'Detroit', 'teamTricode': 'DET', 'wins': 18, 'losses': 40, 'score': 109, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 37}, {'period': 2, 'periodType': 'REGULAR', 'score': 25}, {'period': 3, 'periodType': 'REGULAR', 'score': 22}, {'period': 4, 'periodType': 'REGULAR', 'score': 25}]}, 'awayTeam': {'teamId': 1610612739, 'teamName': 'Cavaliers', 'teamCity': 'Cleveland', 'teamTricode': 'CLE', 'wins': 20, 'losses': 37, 'score': 105, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 22}, {'period': 2, 'periodType': 'REGULAR', 'score': 31}, {'period': 3, 'periodType': 'REGULAR', 'score': 23}, {'period': 4, 'periodType': 'REGULAR', 'score': 29}]}, 'gameLeaders': {'homeLeaders': {'personId': 1630191, 'name': 'Isaiah Stewart', 'jerseyNum': '28', 'position': 'F-C', 'teamTricode': 'DET', 'playerSlug': None, 'points': 18, 'rebounds': 16, 'assists': 0}, 'awayLeaders': {'personId': 1629012, 'name': 'Collin Sexton', 'jerseyNum': '2', 'position': 'G', 'teamTricode': 'CLE', 'playerSlug': None, 'points': 28, 'rebounds': 7, 'assists': 4}}, 'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 1}}, {'gameId': '0022000869', 'gameCode': '20210419/CHIBOS', 'gameStatus': 3, 'gameStatusText': 'Final', 'period': 4, 'gameClock': '', 'gameTimeUTC': '2021-04-19T23:30:00Z', 'gameEt': '2021-04-19T19:30:00Z', 'regulationPeriods': 4, 'seriesGameNumber': '', 'seriesText': '', 'homeTeam': {'teamId': 1610612738, 'teamName': 'Celtics', 'teamCity': 'Boston', 'teamTricode': 'BOS', 'wins': 31, 'losses': 27, 'score': 96, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 30}, {'period': 2, 'periodType': 'REGULAR', 'score': 18}, {'period': 3, 'periodType': 'REGULAR', 'score': 18}, {'period': 4, 'periodType': 'REGULAR', 'score': 30}]}, 'awayTeam': {'teamId': 1610612741, 'teamName': 'Bulls', 'teamCity': 'Chicago', 'teamTricode': 'CHI', 'wins': 24, 'losses': 33, 'score': 102, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 24}, {'period': 2, 'periodType': 'REGULAR', 'score': 18}, {'period': 3, 'periodType': 'REGULAR', 'score': 32}, {'period': 4, 'periodType': 'REGULAR', 'score': 28}]}, 'gameLeaders': {'homeLeaders': {'personId': 1628369, 'name': 'Jayson Tatum', 'jerseyNum': '0', 'position': 'F-G', 'teamTricode': 'BOS', 'playerSlug': None, 'points': 14, 'rebounds': 13, 'assists': 10}, 'awayLeaders': {'personId': 202696, 'name': 'Nikola Vucevic', 'jerseyNum': '9', 'position': 'C', 'teamTricode': 'CHI', 'playerSlug': None, 'points': 29, 'rebounds': 9, 'assists': 2}}, 'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 1}}, {'gameId': '0022000870', 'gameCode': '20210419/GSWPHI', 'gameStatus': 3, 'gameStatusText': 'Final', 'period': 4, 'gameClock': '', 'gameTimeUTC': '2021-04-19T23:30:00Z', 'gameEt': '2021-04-19T19:30:00Z', 'regulationPeriods': 4, 'seriesGameNumber': '', 'seriesText': '', 'homeTeam': {'teamId': 1610612755, 'teamName': '76ers', 'teamCity': 'Philadelphia', 'teamTricode': 'PHI', 'wins': 39, 'losses': 18, 'score': 96, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 24}, {'period': 2, 'periodType': 'REGULAR', 'score': 31}, {'period': 3, 'periodType': 'REGULAR', 'score': 15}, {'period': 4, 'periodType': 'REGULAR', 'score': 26}]}, 'awayTeam': {'teamId': 1610612744, 'teamName': 'Warriors', 'teamCity': 'Golden State', 'teamTricode': 'GSW', 'wins': 29, 'losses': 29, 'score': 107, 'inBonus': None, 'timeoutsRemaining': 0, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 24}, ...

# %%
games = []
for game in data['scoreboard']['games']:
    # home = game['homeTeam']['teamCity'] + " " + game['homeTeam']['teamName']
    # away = game['awayTeam']['teamCity'] + " " + game['awayTeam']['teamName']
    # games.append([home, away])
    games.append([game['homeTeam']['teamTricode'], game['awayTeam']['teamTricode']])
today_games = pd.DataFrame(games, columns=['Home', 'Away'])
today_games
# Out:
#   Home Away
# 0  DET  CLE
# 1  BOS  CHI
# 2  PHI  GSW
# 3  IND  SAS
# 4  MIA  HOU
# 5  WAS  OKC
# 6  MIL  PHX
# 7  DEN  MEM
# 8  LAL  UTA

# %% [markdown]
# # NBA Team Abbreviations

# %%
espn_mapping = {'Atlanta Hawks':'ATL', 'Brooklyn Nets':'BKN', 'Boston Celtics':'BOS', 'Charlotte Hornets':'CHA',
        'Chicago Bulls':'CHI', 'Cleveland Cavaliers':'CLE', 'Dallas Mavericks':'DAL', 'Denver Nuggets':'DEN',
        'Detroit Pistons':'DET', 'Golden State Warriors':'GSW', 'Houston Rockets':'HOU', 'Indiana Pacers':'IND',
        'Los Angeles Clippers':'LAC', 'Los Angeles Lakers':'LAL', 'Memphis Grizzlies':'MEM', 'Miami Heat':'MIA',
        'Milwaukee Bucks':'MIL', 'Minnesota Timberwolves':'MIN', 'New Orleans Pelicans':'NO',
        'New York Knicks':'NYK', 'Oklahoma City Thunder':'OKC', 'Orlando Magic':'ORL', 'Philadelphia 76ers':'PHI',
        'Phoenix Suns':'PHX', 'Portland Trailblazers':'POR', 'Sacramento Kings':'SAC', 'San Antonio Spurs':'SAS',
        'Toronto Raptors':'TOR', 'Utah Jazz':'UTAH', 'Washington Wizards':'WSH'}

# %%
full = list(espn_mapping.keys())
abbr = list(espn_mapping.values())
print(full)
print(abbr)
# Out:
# ['Atlanta Hawks', 'Brooklyn Nets', 'Boston Celtics', 'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Cavaliers', 'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons', 'Golden State Warriors', 'Houston Rockets', 'Indiana Pacers', 'Los Angeles Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies', 'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves', 'New Orleans Pelicans', 'New York Knicks', 'Oklahoma City Thunder', 'Orlando Magic', 'Philadelphia 76ers', 'Phoenix Suns', 'Portland Trailblazers', 'Sacramento Kings', 'San Antonio Spurs', 'Toronto Raptors', 'Utah Jazz', 'Washington Wizards']
# ['ATL', 'BKN', 'BOS', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN', 'NO', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'TOR', 'UTAH', 'WSH']

# %% [markdown]
# # Remaining Games

# %%
url = "https://www.basketball-reference.com/teams/GSW/2021_games.html"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
headers = ['Date','Start (ET)','','Box Score','Home/Away','Opponent','W/L','OT','Score','Opp','W','L','Streak','Notes']

# %%
rows = soup.findAll('tr')[1:]
gms = [[td.getText() for td in rows[i].findAll('td')] for i in range(len(rows))]
gms
# Out:
# [['Tue, Dec 22, 2020',
#   '7:00p',
#   '',
#   'Box Score',
#   '@',
#   'Brooklyn Nets',
#   'L',
#   '',
#   '99',
#   '125',
#   '0',
#   '1',
#   'L 1',
#   ''],
#  ['Fri, Dec 25, 2020',
#   '2:30p',
#   '',
#   'Box Score',
#   '@',
#   'Milwaukee Bucks',
#   'L',
#   '',
#   '99',
#   '138',
#   '0',
#   '2',
#   'L 2',
#   ''],
#  ['Sun, Dec 27, 2020',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Chicago Bulls',
#   'W',
#   '',
#   '129',
#   '128',
#   '1',
#   '2',
#   'W 1',
#   ''],
#  ['Tue, Dec 29, 2020',
#   '7:00p',
#   '',
#   'Box Score',
#   '@',
#   'Detroit Pistons',
#   'W',
#   '',
#   '116',
#   '106',
#   '2',
#   '2',
#   'W 2',
#   ''],
#  ['Fri, Jan 1, 2021',
#   '10:30p',
#   '',
#   'Box Score',
#   '',
#   'Portland Trail Blazers',
#   'L',
#   '',
#   '98',
#   '123',
#   '2',
#   '3',
#   'L 1',
#   ''],
#  ['Sun, Jan 3, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '',
#   'Portland Trail Blazers',
#   'W',
#   '',
#   '137',
#   '122',
#   '3',
#   '3',
#   'W 1',
#   ''],
#  ['Mon, Jan 4, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Sacramento Kings',
#   'W',
#   '',
#   '137',
#   '106',
#   '4',
#   '3',
#   'W 2',
#   ''],
#  ['Wed, Jan 6, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Los Angeles Clippers',
#   'L',
#   '',
#   '101',
#   '108',
#   '4',
#   '4',
#   'L 1',
#   ''],
#  ['Fri, Jan 8, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Los Angeles Clippers',
#   'W',
#   '',
#   '115',
#   '105',
#   '5',
#   '4',
#   'W 1',
#   ''],
#  ['Sun, Jan 10, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '',
#   'Toronto Raptors',
#   'W',
#   '',
#   '106',
#   '105',
#   '6',
#   '4',
#   'W 2',
#   ''],
#  ['Tue, Jan 12, 2021',
#   '10:30p',
#   '',
#   'Box Score',
#   '',
#   'Indiana Pacers',
#   'L',
#   '',
#   '95',
#   '104',
#   '6',
#   '5',
#   'L 1',
#   ''],
#  ['Thu, Jan 14, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Denver Nuggets',
#   'L',
#   '',
#   '104',
#   '114',
#   '6',
#   '6',
#   'L 2',
#   ''],
#  ['Mon, Jan 18, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Los Angeles Lakers',
#   'W',
#   '',
#   '115',
#   '113',
#   '7',
#   '6',
#   'W 1',
#   ''],
#  ['Wed, Jan 20, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'San Antonio Spurs',
#   'W',
#   '',
#   '121',
#   '99',
#   '8',
#   '6',
#   'W 2',
#   ''],
#  ['Thu, Jan 21, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'New York Knicks',
#   'L',
#   '',
#   '104',
#   '119',
#   '8',
#   '7',
#   'L 1',
#   ''],
#  ['Sat, Jan 23, 2021',
#   '9:00p',
#   '',
#   'Box Score',
#   '@',
#   'Utah Jazz',
#   'L',
#   '',
#   '108',
#   '127',
#   '8',
#   '8',
#   'L 2',
#   ''],
#  ['Mon, Jan 25, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Minnesota Timberwolves',
#   'W',
#   '',
#   '130',
#   '108',
#   '9',
#   '8',
#   'W 1',
#   ''],
#  ['Wed, Jan 27, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Minnesota Timberwolves',
#   'W',
#   '',
#   '123',
#   '111',
#   '10',
#   '8',
#   'W 2',
#   ''],
#  ['Thu, Jan 28, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Phoenix Suns',
#   'L',
#   '',
#   '93',
#   '114',
#   '10',
#   '9',
#   'L 1',
#   ''],
#  ['Sat, Jan 30, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Detroit Pistons',
#   'W',
#   '',
#   '118',
#   '91',
#   '11',
#   '9',
#   'W 1',
#   ''],
#  [],
#  ['Tue, Feb 2, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Boston Celtics',
#   'L',
#   '',
#   '107',
#   '111',
#   '11',
#   '10',
#   'L 1',
#   ''],
#  ['Thu, Feb 4, 2021',
#   '7:30p',
#   '',
#   'Box Score',
#   '@',
#   'Dallas Mavericks',
#   'W',
#   '',
#   '147',
#   '116',
#   '12',
#   '10',
#   'W 1',
#   ''],
#  ['Sat, Feb 6, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '@',
#   'Dallas Mavericks',
#   'L',
#   '',
#   '132',
#   '134',
#   '12',
#   '11',
#   'L 1',
#   ''],
#  ['Mon, Feb 8, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '@',
#   'San Antonio Spurs',
#   'L',
#   '',
#   '100',
#   '105',
#   '12',
#   '12',
#   'L 2',
#   ''],
#  ['Tue, Feb 9, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '@',
#   'San Antonio Spurs',
#   'W',
#   '',
#   '114',
#   '91',
#   '13',
#   '12',
#   'W 1',
#   ''],
#  ['Thu, Feb 11, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Orlando Magic',
#   'W',
#   '',
#   '111',
#   '105',
#   '14',
#   '12',
#   'W 2',
#   ''],
#  ['Sat, Feb 13, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '',
#   'Brooklyn Nets',
#   'L',
#   '',
#   '117',
#   '134',
#   '14',
#   '13',
#   'L 1',
#   ''],
#  ['Mon, Feb 15, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Cleveland Cavaliers',
#   'W',
#   '',
#   '129',
#   '98',
#   '15',
#   '13',
#   'W 1',
#   ''],
#  ['Wed, Feb 17, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Miami Heat',
#   'W',
#   'OT',
#   '120',
#   '112',
#   '16',
#   '13',
#   'W 2',
#   ''],
#  ['Fri, Feb 19, 2021',
#   '7:00p',
#   '',
#   'Box Score',
#   '@',
#   'Orlando Magic',
#   'L',
#   '',
#   '120',
#   '124',
#   '16',
#   '14',
#   'L 1',
#   ''],
#  ['Sat, Feb 20, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Charlotte Hornets',
#   'L',
#   '',
#   '100',
#   '102',
#   '16',
#   '15',
#   'L 2',
#   ''],
#  ['Tue, Feb 23, 2021',
#   '7:30p',
#   '',
#   'Box Score',
#   '@',
#   'New York Knicks',
#   'W',
#   '',
#   '114',
#   '106',
#   '17',
#   '15',
#   'W 1',
#   ''],
#  ['Wed, Feb 24, 2021',
#   '7:30p',
#   '',
#   'Box Score',
#   '@',
#   'Indiana Pacers',
#   'W',
#   '',
#   '111',
#   '107',
#   '18',
#   '15',
#   'W 2',
#   ''],
#  ['Fri, Feb 26, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Charlotte Hornets',
#   'W',
#   '',
#   '130',
#   '121',
#   '19',
#   '15',
#   'W 3',
#   ''],
#  ['Sun, Feb 28, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Los Angeles Lakers',
#   'L',
#   '',
#   '91',
#   '117',
#   '19',
#   '16',
#   'L 1',
#   ''],
#  ['Wed, Mar 3, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Portland Trail Blazers',
#   'L',
#   '',
#   '106',
#   '108',
#   '19',
#   '17',
#   'L 2',
#   ''],
#  ['Thu, Mar 4, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Phoenix Suns',
#   'L',
#   '',
#   '98',
#   '120',
#   '19',
#   '18',
#   'L 3',
#   ''],
#  ['Thu, Mar 11, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Los Angeles Clippers',
#   'L',
#   '',
#   '104',
#   '130',
#   '19',
#   '19',
#   'L 4',
#   ''],
#  ['Sun, Mar 14, 2021',
#   '4:00p',
#   '',
#   'Box Score',
#   '',
#   'Utah Jazz',
#   'W',
#   '',
#   '131',
#   '119',
#   '20',
#   '19',
#   'W 1',
#   ''],
#  ['Mon, Mar 15, 2021',
#   '10:30p',
#   '',
#   'Box Score',
#   '',
#   'Los Angeles Lakers',
#   'L',
#   '',
#   '97',
#   '128',
#   '20',
#   '20',
#   'L 1',
#   ''],
#  [],
#  ['Wed, Mar 17, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Houston Rockets',
#   'W',
#   '',
#   '108',
#   '94',
#   '21',
#   '20',
#   'W 1',
#   ''],
#  ['Fri, Mar 19, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Memphis Grizzlies',
#   'W',
#   '',
#   '116',
#   '103',
#   '22',
#   '20',
#   'W 2',
#   ''],
#  ['Sat, Mar 20, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Memphis Grizzlies',
#   'L',
#   '',
#   '103',
#   '111',
#   '22',
#   '21',
#   'L 1',
#   ''],
#  ['Tue, Mar 23, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Philadelphia 76ers',
#   'L',
#   '',
#   '98',
#   '108',
#   '22',
#   '22',
#   'L 2',
#   ''],
#  ['Thu, Mar 25, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '@',
#   'Sacramento Kings',
#   'L',
#   '',
#   '119',
#   '141',
#   '22',
#   '23',
#   'L 3',
#   ''],
#  ['Fri, Mar 26, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Atlanta Hawks',
#   'L',
#   '',
#   '108',
#   '124',
#   '22',
#   '24',
#   'L 4',
#   ''],
#  ['Mon, Mar 29, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Chicago Bulls',
#   'W',
#   '',
#   '116',
#   '102',
#   '23',
#   '24',
#   'W 1',
#   ''],
#  ['Thu, Apr 1, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Miami Heat',
#   'L',
#   '',
#   '109',
#   '116',
#   '23',
#   '25',
#   'L 1',
#   ''],
#  ['Fri, Apr 2, 2021',
#   '7:00p',
#   '',
#   'Box Score',
#   '@',
#   'Toronto Raptors',
#   'L',
#   '',
#   '77',
#   '130',
#   '23',
#   '26',
#   'L 2',
#   ''],
#  ['Sun, Apr 4, 2021',
#   '7:30p',
#   '',
#   'Box Score',
#   '@',
#   'Atlanta Hawks',
#   'L',
#   '',
#   '111',
#   '117',
#   '23',
#   '27',
#   'L 3',
#   ''],
#  ['Tue, Apr 6, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Milwaukee Bucks',
#   'W',
#   '',
#   '122',
#   '121',
#   '24',
#   '27',
#   'W 1',
#   ''],
#  ['Fri, Apr 9, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Washington Wizards',
#   'L',
#   '',
#   '107',
#   '110',
#   '24',
#   '28',
#   'L 1',
#   ''],
#  ['Sat, Apr 10, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Houston Rockets',
#   'W',
#   '',
#   '125',
#   '109',
#   '25',
#   '28',
#   'W 1',
#   ''],
#  ['Mon, Apr 12, 2021',
#   '10:00p',
#   '',
#   'Box Score',
#   '',
#   'Denver Nuggets',
#   'W',
#   '',
#   '116',
#   '107',
#   '26',
#   '28',
#   'W 2',
#   ''],
#  ['Wed, Apr 14, 2021',
#   '9:00p',
#   '',
#   'Box Score',
#   '@',
#   'Oklahoma City Thunder',
#   'W',
#   '',
#   '147',
#   '109',
#   '27',
#   '28',
#   'W 3',
#   ''],
#  ['Thu, Apr 15, 2021',
#   '8:00p',
#   '',
#   'Box Score',
#   '@',
#   'Cleveland Cavaliers',
#   'W',
#   '',
#   '119',
#   '101',
#   '28',
#   '28',
#   'W 4',
#   ''],
#  ['Sat, Apr 17, 2021',
#   '8:30p',
#   '',
#   'Box Score',
#   '@',
#   'Boston Celtics',
#   'L',
#   '',
#   '114',
#   '119',
#   '28',
#   '29',
#   'L 1',
#   ''],
#  ['Mon, Apr 19, 2021',
#   '7:30p',
#   '',
#   '',
#   '@',
#   'Philadelphia 76ers',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Wed, Apr 21, 2021',
#   '7:00p',
#   '',
#   '',
#   '@',
#   'Washington Wizards',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Fri, Apr 23, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Denver Nuggets',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  [],
#  ['Sun, Apr 25, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Sacramento Kings',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tue, Apr 27, 2021',
#   '9:30p',
#   '',
#   '',
#   '',
#   'Dallas Mavericks',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Thu, Apr 29, 2021',
#   '8:00p',
#   '',
#   '',
#   '@',
#   'Minnesota Timberwolves',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Sat, May 1, 2021',
#   '7:30p',
#   '',
#   '',
#   '@',
#   'Houston Rockets',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Mon, May 3, 2021',
#   '7:30p',
#   '',
#   '',
#   '@',
#   'New Orleans Pelicans',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tue, May 4, 2021',
#   '8:00p',
#   '',
#   '',
#   '@',
#   'New Orleans Pelicans',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Thu, May 6, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Oklahoma City Thunder',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Sat, May 8, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Oklahoma City Thunder',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Mon, May 10, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Utah Jazz',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tue, May 11, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'Phoenix Suns',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Fri, May 14, 2021',
#   '10:00p',
#   '',
#   '',
#   '',
#   'New Orleans Pelicans',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Sun, May 16, 2021',
#   '',
#   '',
#   '',
#   '',
#   'Memphis Grizzlies',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %%
games = pd.DataFrame(gms, columns = headers)
future_games = games[(games['W/L'] == '')]
future_games = future_games.reset_index()
future_games = future_games.drop(columns=['index','','Box Score','W/L','OT','Score','Opp','W','L','Streak','Notes'])
future_games['Opponent'] = future_games['Opponent'].map(espn_mapping)
future_games
# Out:
#                  Date Start (ET) Home/Away Opponent
# 0   Mon, Apr 19, 2021      7:30p         @      PHI
# 1   Wed, Apr 21, 2021      7:00p         @      WSH
# 2   Fri, Apr 23, 2021     10:00p                DEN
# 3   Sun, Apr 25, 2021     10:00p                SAC
# 4   Tue, Apr 27, 2021      9:30p                DAL
# 5   Thu, Apr 29, 2021      8:00p         @      MIN
# 6    Sat, May 1, 2021      7:30p         @      HOU
# 7    Mon, May 3, 2021      7:30p         @       NO
# 8    Tue, May 4, 2021      8:00p         @       NO
# 9    Thu, May 6, 2021     10:00p                OKC
# 10   Sat, May 8, 2021     10:00p                OKC
# 11  Mon, May 10, 2021     10:00p               UTAH
# 12  Tue, May 11, 2021     10:00p                PHX
# 13  Fri, May 14, 2021     10:00p                 NO
# 14  Sun, May 16, 2021                           MEM

# %% [markdown]
# # Depth Charts

# %%
depth_charts = {}
for d in abbr:
    url = "https://www.espn.com/nba/team/depth/_/name/" + d
    html = urlopen(url)
    soup = BeautifulSoup(html)
    rows = soup.findAll('tr')
    depth = []
    for r in rows[7:]:
        position = []
        for a in r.findAll('a'):
            position.append(a.getText())
        depth.append(position)
    list(map(list, zip(*depth)))
    depth_charts[d] = depth
    sleep(1)
print(depth_charts)
# Out:
# {'ATL': [['Trae Young', 'Brandon Goodwin', 'Lou Williams', 'Kris Dunn', 'Kevin Huerter'], ['Bogdan Bogdanovic', 'Lou Williams', 'Kevin Huerter', 'Kris Dunn', 'Tony Snell'], ["De'Andre Hunter", 'Kevin Huerter', 'Tony Snell', 'Solomon Hill', 'Danilo Gallinari'], ['John Collins', 'Danilo Gallinari', 'Solomon Hill', 'Tony Snell', "De'Andre Hunter"], ['Clint Capela', 'Onyeka Okongwu', 'Nathan Knight', 'John Collins', 'Bruno Fernando']], 'BKN': [['James Harden', 'Bruce Brown', 'Kyrie Irving', 'Tyler Johnson', 'Landry Shamet'], ['Kyrie Irving', 'Landry Shamet', 'Joe Harris', 'Bruce Brown', 'James Harden'], ['Joe Harris', 'Timothe Luwawu-Cabarrot', 'Bruce Brown', 'Alize Johnson', 'Kevin Durant'], ['Kevin Durant', 'Jeff Green', 'Blake Griffin', 'Joe Harris', 'Timothe Luwawu-Cabarrot'], ['Blake Griffin', 'Nicolas Claxton', 'DeAndre Jordan', 'Jeff Green', 'Kevin Durant']], 'BOS': [['Kemba Walker', 'Marcus Smart', 'Payton Pritchard', 'Tremont Waters', 'Carsen Edwards'], ['Marcus Smart', 'Evan Fournier', 'Romeo Langford', 'Jaylen Brown', 'Aaron Nesmith'], ['Jaylen Brown', 'Grant Williams', 'Evan Fournier', 'Romeo Langford', 'Semi Ojeleye'], ['Jayson Tatum', 'Jabari Parker', 'Semi Ojeleye', 'Grant Williams', 'Luke Kornet'], ['Robert Williams III', 'Tristan Thompson', 'Luke Kornet', 'Grant Williams', 'Tacko Fall']], 'CHA': [["Devonte' Graham", 'Terry Rozier', 'Brad Wanamaker', 'Malik Monk', 'Cody Martin'], ['Terry Rozier', 'Malik Monk', 'Caleb Martin', "Devonte' Graham", 'Cody Martin'], ['Miles Bridges', 'Cody Martin', 'Caleb Martin', 'Terry Rozier', 'Jalen McDaniels'], ['J